# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (8.31.0)
# Requirement already satisfied: colorama in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack_data in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from stack_data->ipython) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\coding\repositories\ru-hackathon\myvenv\lib\site-packages (from stack_data->ipython) (0.2.3)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import IPython.display as ipd
import riva.client
import sounddevice as sd

# %%
auth = riva.client.Auth(uri='localhost:50051')

riva_tts = riva.client.SpeechSynthesisService(auth)

# %%
sample_rate_hz = 44100
req = { 
        "language_code"  : "en-US",
        "encoding"       : riva.client.AudioEncoding.LINEAR_PCM ,   # LINEAR_PCM and OGGOPUS encodings are supported
        "sample_rate_hz" : sample_rate_hz,                          # Generate 44.1KHz audio
        "voice_name"     : "English-US.Male-Happy"                    # The name of the voice to generate
}

# %%
text = """<speak>I <emphasis>love</emphasis> you</speak>"""
req["text"] = text
resp = riva_tts.synthesize(**req)
audio_samples = np.frombuffer(resp.audio, dtype=np.int16)



#ipd.Audio(audio_samples, rate=sample_rate_hz)

 
# Play audio
sd.play(audio_samples, sample_rate_hz)
sd.wait()  # Wait until audio finishes playing

# %%
# Out:
# SSML Text:  <speak>This is a normal sentence</speak>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# --------------------------------------------
# SSML Text:  <speak><prosody pitch="0" rate="80%">This is also a normal sentence</prosody></speak>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# --------------------------------------------
